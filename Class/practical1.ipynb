# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/shubh/Desktop/Programs/Aiml/Class/homeprices-1 for Multi Linear Regression.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
plt.xlabel("Area")
plt.ylabel("Price")
plt.scatter(df['area'], df['price'])
plt.show()

# %%
X = df[['area']]
y = df['price']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
x_train
# Out:
#    area
# 5  4100
# 2  3200
# 4  4000
# 3  3600

# %%
x_test
# Out:
#    area
# 0  2600
# 1  3000

# %%
y_test
# Out:
# 0    550000
# 1    565000
# Name: price, dtype: int64

# %%
y_train
# Out:
# 5    810000
# 2    610000
# 4    760000
# 3    595000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.plot(x_train,y_train,'bo')

# %%
plt.plot(x_test,y_test,'ro--')

# %%
reg.predict([[3300]])
# Out:
# /Users/shubh/.pyenv/versions/3.14.0/lib/python3.14/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([594827.5862069])

# %%
reg.coef_
# Out:
# array([232.75862069])

# %%
reg.intercept_
# Out:
# np.float64(-173275.86206896568)

# %%
reg.score(x_train,y_train)
# Out:
# 0.7930661494563696
