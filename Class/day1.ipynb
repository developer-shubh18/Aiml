# %%
import numpy as np
arr_1d=np.array([1,2,3,4])
print(arr_1d)

# %%
type(arr_1d)

# %%
arr_2d=np.array([[1,2,3,4],[11,22,33,44],[111,222,333,444]])
print(arr_2d)

# %%
arr_2d.ndim

# %%
arr_md=np.array([[[1,2,3,4],[11,22,33,44],[111,222,333,444],[22,33,44,55]],
[[12,13,14,15],[22,23,24,25],[1,1,1,1],[2,2,2,2]]])
print(arr_md)

# %%
arr_md.ndim

# %%
arr_1d.size

# %%
arr_2d.size

# %%
arr_md.size

# %%
arr_2d.shape

# %%
arr_md.shape

# %%
arr_md.dtype

# %%
arr_2d.dtype
arr_1d.dtype

# %%
arr_2d

# %%
max_1s=np.array([[1,1,1],[1,1,1],[1,1,1]])
print(max_1s)

# %%
maxone=np.ones(5)
print(maxone)

# %%
max_one = np.ones((3,4))
print(max_one)

# %%
max_one = np.ones((3,4),dtype=int)
print(max_one)

# %%
max_one = np.zeros((3,4))
print(max_one)

# %%
max_one = np.zeros((3,4),dtype=bool)
print(max_one)

# %%
max_one = np.zeros((3,4),dtype=int)
print(max_one)

# %%
max_one = np.zeros((3,4),dtype=str)
print(max_one)

# %%
em_str=''
print(bool(em_str))

# %%
em_mx=np.empty((3,3))
print(em_mx)

# %%
# NUMPY FUNCTION

# %%
import numpy as np

# %%
num=np.arange(1,13)
print(num)

# %%
num=np.arange(1,50,4)
print(num)
np.linspace(1,20,6) 
# start = 1
# stop = 20
# num = 7
# number of intervals = 7 − 1 = 6
# Step size:
# frac{20 - 1}/{6} = frac{19}/{6} approx 3.1666667

# %%
# RESHAPE

# %%
arr_1d= np.arange(1,19)
print(arr_1d)

# %%
arr_2d=arr_1d.reshape(6,3)
print(arr_2d)
# RAVEL
arr_2d.ravel()

# %%
arr_3d=arr_1d.reshape(2,3,3)
print(arr_3d)

# %%
ar=np.arange(1,21).reshape(5,4)
print(ar)

# %%
# REVEL & FLATTEN & TRANSPOSE

# %%
ar=np.arange(1,21).reshape(5,4)
print(ar)
ar.ravel()

# %%
ar=np.arange(1,21).reshape(5,4)
print(ar)
ar.flatten()

# %%
ar=np.arange(1,21).reshape(5,4)
print(ar)
ar.transpose()

# %%
ar=np.arange(1,21).reshape(5,4)
print(ar)
ar.T

# %%
# MATHEMATICS OPERATION USING NUMPY

# %%
import numpy as np

# %%
arr1=np.arange(1,10).reshape(3,3)
arr2=np.arange(11,20).reshape(3,3)
print(arr1)
print(arr2)

# %%
print(arr1+arr2)

# %%
print(arr2-arr1)

# %%
print(arr1*arr2)

# %%
print(arr1@arr2)

# %%
arr1.dot(arr2)

# %%
np.add(arr1,arr2)

# %%
np.subtract(arr2,arr1)

# %%
np.divide(arr2,arr1)

# %%
np.multiply(arr1,arr2)

# %% [markdown]
# matric production 2 method sa kar skat ho
# 1.@
# 2. .dot

# %%
arr1@arr2

# %%
arr1.dot(arr2)

# %%
arr1

# %%
# .MAXIMUM VALUE FIELD

# %%
arr1.max()

# %% [markdown]
# maximum value ka index find out karna

# %%
arr1.argmax()

# %%
# each coloum/row ki value find karna
# .max(axis=0) for each colom ki maximum value find out karna
# .max(axis=1) for each row ki maximum value find out karna

# %%
arr1.max(axis=1)

# %%
arr1.max(axis=0)

# %%
arr1.min(axis=1)

# %%
sum=np.sum(arr2)
print(sum)

# %%
np.sum(arr2)

# %%
np.sqrt(arr1)

# %%
np.mean((arr1))

# %%
np.std(arr2)

# %%
np.exp(arr2)

# %%
np.log(arr2)

# %%
np.log10(arr2)

# %% [markdown]
# PYTHON NUMPY ARRAY SLICING

# %%
mx=np.arange(1,101).reshape(10,10)
print(mx)

# %%
mx[0,0]

# %%
mx[8,7]

# %%
mx[:]

# %%
mx[:,2:6]

# %%
mx[2:6,:]

# %%
mx[3:6,4:8]

# %%
mx[:,0:4]

# %%
mx[:,0:1].ndim

# %%
mx[::]

# %%
mx.itemsize

# %%
mx.dtype

# %%
32/8
