# %%
import pandas as pd
import numpy as np
import statistics as stats
import matplotlib as plt

# %%
f1= pd.read_excel("Statics.xlsx")

# %%
f1.shape
# Out:
# (100, 2)

# %%
f1.head()
# Out:
#    Customer  Age
# 0         1   39
# 1         2   41
# 2         3   56
# 3         4   32
# 4         5   19

# %%
f1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Customer  100 non-null    int64
#  1   Age       100 non-null    int64
# dtypes: int64(2)
# memory usage: 1.7 KB

# %%
f1.dropna(inplace=True)

# %%
f1.columns
# Out:
# Index(['Customer', 'Age'], dtype='object')
